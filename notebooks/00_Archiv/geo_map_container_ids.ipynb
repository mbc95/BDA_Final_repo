# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 20000)
pd.set_option('display.max_rows', 500)

import csv

import json
import urllib
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.plotting import gmap
import numpy as np

from bokeh.io import curdoc, show
from bokeh.models import ColumnDataSource, Grid, LinearAxis, Plot, Text

# %%
df = pd.read_csv('../data/preprocessed/cleaned_data_v3.csv', delimiter=",")
AUTH_KEY = "AIzaSyBO73vnqQdVpW-R7brR0Dumg0AQRkL5_a0"

# %%
geo_df = df.groupby(by=["container_id"], as_index=False).first()
geo_df
# Out:
#     container_id       id  messungszähler  height_in_cm  temperatur_in_grad  \
# 0              1  4110576             193           112                14.0
# 1              2  4110211             210            76                20.0
# 2              3  4110164             191           112                18.0
# 3              4  4110544             198           114                20.0
# 4              5  4111091             215           132                10.0
# 5              6  4111086              53            60                11.0
# 6              7  4110598             188           132                12.0
# 7              8  4110827             236            74                14.0
# 8              9  4110513             217           124                12.0
# 9             10  4111089              24           102                11.0
# 10            11  4110160             187            80                18.0
# ...

# %%
#geo_df_2 = geo_df.groupby(['laengengrad'])['container_id'].apply(lambda x: ''.join(str(x))).reset_index()
geo_df['container_id'] = geo_df['container_id'].astype(str)
geo_df_2 = geo_df.groupby(['laengengrad', 'breitengrad'], as_index = False).agg({'container_id': '+'.join})

# %%
geo_df_2
# Out:
#     laengengrad  breitengrad       container_id
# 0     50.110922     8.682127         3+27+46+67
# 1     50.118095     8.768628                 20
# 2     50.119270     8.770680           44+65+70
# 3     50.123045     8.765538              12+57
# 4     50.123940     8.762620        19+35+48+61
# 5     50.125186     8.710195              52+71
# 6     50.125620     8.710940              43+51
# 7     50.126166     8.765479              14+15
# 8     50.126541     8.698816  21+28+40+47+66+77
# 9     50.126570     8.694229                  8
# 10    50.128183     8.704522     13+31+34+49+53
# 11    50.128856     8.710925       4+7+50+72+73
# 12    50.129386     8.700707            5+56+74
# 13    50.129507     8.706566     32+36+37+58+68
# 14    50.130200     8.699243                 69
# 15    50.130257     8.709095              25+26
# 16    50.131869     8.706368           10+17+59
# 17    50.131949     8.695304           30+39+45
# 18    50.133020     8.710950               9+64
# ...

# %%
output_file("../data/modeling/plots/bokeh_v2.html")

map_options = GMapOptions(lat = 50.13, lng = 8.73, map_type = "roadmap", zoom = 12)
bokeh_plot = gmap(AUTH_KEY, map_options, title = "Container locations")

bokeh_plot.circle(x = "breitengrad", y = "laengengrad", size = 10, fill_alpha = 0.8, source = geo_df_2)

source = ColumnDataSource(dict(x = geo_df_2['breitengrad'], y = geo_df_2['laengengrad'], text = geo_df_2['container_id']))

glyph = Text(x="x", y="y", text="text", angle=0, text_color="#000000", text_font_size="10px")
bokeh_plot.add_glyph(source, glyph)

show(bokeh_plot)
