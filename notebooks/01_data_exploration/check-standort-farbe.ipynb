# %%
# Import libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', 20000)
pd.set_option('display.max_rows', 500)

df = pd.read_csv('../data/preprocessed/cleaned_data_v7.csv', delimiter=",")
df = df[['container_id', 'farbe_brown', 'farbe_green', 'farbe_white', 'breitengrad','laengengrad']]

# %% [markdown]
# # Sind Farben an einem Standort immer einzigartig?
# -  Duplicates löschen
# - nach Breitengrad sortieren

# %%
df=df.drop_duplicates( ignore_index=True)
df=df.sort_values(by=['breitengrad'])

# %%
df
# Out:
#     container_id  farbe_brown  farbe_green  farbe_white  breitengrad  \
# 31            46            0            1            0     8.682127
# 74             3            0            0            1     8.682127
# 10            67            0            0            1     8.682127
# 50            27            1            0            0     8.682127
# 69             8            1            0            0     8.694229
# 38            39            1            0            0     8.695304
# 32            45            0            1            0     8.695304
# 47            30            0            0            1     8.695304
# 75             2            1            0            0     8.697431
# 22            55            0            0            1     8.697431
# 61            16            0            1            0     8.697431
# 59            18            1            0            0     8.698018
# 1             76            0            1            0     8.698018
# ...

# %% [markdown]
# Nei, es gibt mehrere gleichfarbige Container an Standorten. -> One-Hot encoded ID also erforderlich, da über die Kombination Standort-Farbe der Container nicht bestimmt werden kann.
